# %%
# !pip install pandas

# %%
import pandas as pd

# %%
empdata = [[101,'keshav',50000],[102,'madhav',60000],[103,'rakesh',70000]]

# %%
#creating dataframe from list of list

# %%
df = pd.DataFrame(empdata)

# %%
df
# Out:
#      0       1      2
# 0  101  keshav  50000
# 1  102  madhav  60000
# 2  103  rakesh  70000

# %%
# !pip install pymysql

# %%
import pymysql

# %%
conn = pymysql.connect(host='localhost',
                      user = 'root',
                      password = 'root',
                      port = 3306,
                      database = 'depractice'
                     )

# %%
cur = conn.cursor()

# %%
cur.execute("select * from emp")
# Out:
# 3

# %%
data = cur.fetchall()

# %%
data
# Out:
# ((101, 'rakesh'), (102, 'madhav'), (103, 'atul'))

# %%
#it came as tuple of tuple from mysql database depractive emp table

# %%
#to convert it into dataframe

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#      0       1
# 0  101  rakesh
# 1  102  madhav
# 2  103    atul

# %%
#to set the column name

# %%
df = pd.DataFrame(data,columns=['id','name'])

# %%
df
# Out:
#     id    name
# 0  101  rakesh
# 1  102  madhav
# 2  103    atul

# %%
#DATAFRAME creation using dictionary

# %%
student_iq = {
    'name': ['aka','biv','kau'],
    'id': [100,101,102],
    'iq': [80, 90,100]
}

# %%
students=pd.DataFrame(student_iq)

# %%
students
# Out:
#   name   id   iq
# 0  aka  100   80
# 1  biv  101   90
# 2  kau  102  100

# %%
#tuple of tuple - DF create

# %%
player_cat = (('rohit', 10000, 'mumbai'),('virat', 12000, 'delhi'),('yuvi',9000,'punjab'))

# %%
category = pd.DataFrame(player_cat)

# %%
category
# Out:
#        0      1       2
# 0  rohit  10000  mumbai
# 1  virat  12000   delhi
# 2   yuvi   9000  punjab

# %%
category = pd.DataFrame(player_cat,columns=['name','runs','city'])

# %%
category
# Out:
#     name   runs    city
# 0  rohit  10000  mumbai
# 1  virat  12000   delhi
# 2   yuvi   9000  punjab

# %%
#list of tuple -creation

# %%
play = [('rohit', 10000, 'mumbai'),('virat', 12000, 'delhi'),('yuvi',9000,'punjab')]

# %%
pd.DataFrame(play)
# Out:
#        0      1       2
# 0  rohit  10000  mumbai
# 1  virat  12000   delhi
# 2   yuvi   9000  punjab

# %%
pd.DataFrame(play,columns=['name','matches','address'])
# Out:
#     name  matches address
# 0  rohit    10000  mumbai
# 1  virat    12000   delhi
# 2   yuvi     9000  punjab

# %%
#tuple of list -creation DF

# %%
cric = (['rohit', 10000, 'mumbai'],['virat', 12000, 'delhi'],['yuvi',9000,'punjab'])

# %%
pd.DataFrame(cric)
# Out:
#        0      1       2
# 0  rohit  10000  mumbai
# 1  virat  12000   delhi
# 2   yuvi   9000  punjab

# %%
pd.DataFrame(cric,columns=['player','balls_played','venue'])
# Out:
#   player  balls_played   venue
# 0  rohit         10000  mumbai
# 1  virat         12000   delhi
# 2   yuvi          9000  punjab

# %%
#From File - using read_csv

# %%
pd.read_csv("emprecords.csv")
# Out:
#     id    name       sal
# 0  101  keshav     54353
# 1  102  madhav    434342
# 2  103  rakesh  23432432
# 3  104    amit    432432

# %%
pd.read_csv(r"C:\Users\USER\Desktop\Data Engineering\SQL practice_Campusx\Pandas data sets\batsman_runs_ipl.csv")
# Out:
#              batter  batsman_run
# 0    A Ashish Reddy          280
# 1          A Badoni          161
# 2        A Chandila            4
# 3          A Chopra           53
# 4       A Choudhary           25
# ..              ...          ...
# 600      Yash Dayal            0
# 601   Yashpal Singh           47
# 602     Younis Khan            3
# 603    Yuvraj Singh         2754
# 604          Z Khan          117
#
# [605 rows x 2 columns]

# %%
pd.read_csv("C:\\Users\\USER\\Desktop\\Data Engineering\\SQL practice_Campusx\\Pandas data sets\\movies (1).csv")
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
pd.read_csv("C:/Users/USER/Desktop/Data Engineering/SQL practice_Campusx/Pandas data sets/diabetes.csv")
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
pd.read_csv(r"C:\Users\USER\Desktop\Data Engineering\SQL practice_Campusx\Pandas data sets\diabetes.csv",usecols=['Pregnancies','Glucose','BloodPressure'])
# Out:
#      Pregnancies  Glucose  BloodPressure
# 0              6      148             72
# 1              1       85             66
# 2              8      183             64
# 3              1       89             66
# 4              0      137             40
# ..           ...      ...            ...
# 763           10      101             76
# 764            2      122             70
# 765            5      121             72
# 766            1      126             60
# 767            1       93             70
#
# [768 rows x 3 columns]

# %%
pd.read_csv(r"C:\Users\USER\Desktop\Data Engineering\SQL practice_Campusx\Pandas data sets\batsman_runs_ipl.csv",usecols=['batter'])
# Out:
#              batter
# 0    A Ashish Reddy
# 1          A Badoni
# 2        A Chandila
# 3          A Chopra
# 4       A Choudhary
# ..              ...
# 600      Yash Dayal
# 601   Yashpal Singh
# 602     Younis Khan
# 603    Yuvraj Singh
# 604          Z Khan
#
# [605 rows x 1 columns]

# %%
#read Json file

# %%
pd.read_json(r"C:\Users\USER\Desktop\AI Nexus\Pandas\Notes\sample_data.json")
# Out:
#    id     name  age       city
# 0   1    Alice   25      Delhi
# 1   2      Bob   30     Mumbai
# 2   3  Charlie   28    Kolkata
# 3   4    David   35  Bengaluru
# 4   5      Eva   22    Chennai
# 5   6    Frank   40  Hyderabad
# 6   7    Grace   27       Pune
# 7   8    Helen   32     Jaipur
# 8   9      Ian   29  Ahmedabad
# 9  10     Jane   26   Guwahati

# %%
import pandas as pd

# %%
pd.read_json(r"C:\Users\USER\Desktop\AI Nexus\Pandas\Notes\emp.json")
# Out:
#                                            Employees
# 0  {'userId': 'rirani', 'jobTitleName': 'Develope...
# 1  {'userId': 'nirani', 'jobTitleName': 'Develope...
# 2  {'userId': 'thanks', 'jobTitleName': 'Program ...

# %%
import json
with open (r"C:\Users\USER\Desktop\AI Nexus\Pandas\Notes\emp.json") as fp:
    data = json.load(fp)

# %%
data
# Out:
# {'Employees': [{'userId': 'rirani',
#    'jobTitleName': 'Developer',
#    'firstName': 'Romin',
#    'lastName': 'Irani',
#    'preferredFullName': 'Romin Irani',
#    'employeeCode': 'E1',
#    'region': 'CA',
#    'phoneNumber': '408-1234567',
#    'emailAddress': 'romin.k.irani@gmail.com'},
#   {'userId': 'nirani',
#    'jobTitleName': 'Developer',
#    'firstName': 'Neil',
#    'lastName': 'Irani',
#    'preferredFullName': 'Neil Irani',
#    'employeeCode': 'E2',
#    'region': 'CA',
#    'phoneNumber': '408-1111111',
#    'emailAddress': 'neilrirani@gmail.com'},
#   {'userId': 'thanks',
#    'jobTitleName': 'Program Directory',
#    'firstName': 'Tom',
#    'lastName': 'Hanks',
#    'preferredFullName': 'Tom Hanks',
#    'employeeCode': 'E3',
#    'region': 'CA',
#    'phoneNumber': '408-2222222',
#    'emailAddress': 'tomhanks@gmail.com'}]}

# %%
data['Employees']
# Out:
# [{'userId': 'rirani',
#   'jobTitleName': 'Developer',
#   'firstName': 'Romin',
#   'lastName': 'Irani',
#   'preferredFullName': 'Romin Irani',
#   'employeeCode': 'E1',
#   'region': 'CA',
#   'phoneNumber': '408-1234567',
#   'emailAddress': 'romin.k.irani@gmail.com'},
#  {'userId': 'nirani',
#   'jobTitleName': 'Developer',
#   'firstName': 'Neil',
#   'lastName': 'Irani',
#   'preferredFullName': 'Neil Irani',
#   'employeeCode': 'E2',
#   'region': 'CA',
#   'phoneNumber': '408-1111111',
#   'emailAddress': 'neilrirani@gmail.com'},
#  {'userId': 'thanks',
#   'jobTitleName': 'Program Directory',
#   'firstName': 'Tom',
#   'lastName': 'Hanks',
#   'preferredFullName': 'Tom Hanks',
#   'employeeCode': 'E3',
#   'region': 'CA',
#   'phoneNumber': '408-2222222',
#   'emailAddress': 'tomhanks@gmail.com'}]

# %%
pd.DataFrame(data['Employees'])
# Out:
#    userId       jobTitleName firstName lastName preferredFullName  \
# 0  rirani          Developer     Romin    Irani       Romin Irani
# 1  nirani          Developer      Neil    Irani        Neil Irani
# 2  thanks  Program Directory       Tom    Hanks         Tom Hanks
#
#   employeeCode region  phoneNumber             emailAddress
# 0           E1     CA  408-1234567  romin.k.irani@gmail.com
# 1           E2     CA  408-1111111     neilrirani@gmail.com
# 2           E3     CA  408-2222222       tomhanks@gmail.com

# %%
# Assignment - nested json to DataFrame

# %%
data = """
{
  "orders": [
    {
      "order_id": "ORD1001",
      "customer": {
        "name": "John Doe",
        "contact": {
          "email": "john@example.com",
          "phone": "9876543210"
        }
      },
      "items": [
        {"item_id": "I101", "name": "Laptop", "price": 60000, "qty": 1},
        {"item_id": "I102", "name": "Mouse", "price": 1200, "qty": 2}
      ],
      "shipping": {
        "address": "Baner, Pune",
        "method": "Express",
        "tracking": {
          "carrier": "Bluedart",
          "tracking_id": "BD12345IN"
        }
      }
    },
    {
      "order_id": "ORD1002",
      "customer": {
        "name": "Arjun Singh",
        "contact": {
          "email": "arjun@example.com",
          "phone": "9988776655"
        }
      },
      "items": [
        {"item_id": "I103", "name": "Keyboard", "price": 2500, "qty": 1}
      ],
      "shipping": {
        "address": "Salt Lake, Kolkata",
        "method": "Standard",
        "tracking": {
          "carrier": "Delhivery",
          "tracking_id": "DL99887IN"
        }
      }
    }
  ]
}
"""

# %%
data = json.loads(data)

# %%
data
# Out:
# {'orders': [{'order_id': 'ORD1001',
#    'customer': {'name': 'John Doe',
#     'contact': {'email': 'john@example.com', 'phone': '9876543210'}},
#    'items': [{'item_id': 'I101', 'name': 'Laptop', 'price': 60000, 'qty': 1},
#     {'item_id': 'I102', 'name': 'Mouse', 'price': 1200, 'qty': 2}],
#    'shipping': {'address': 'Baner, Pune',
#     'method': 'Express',
#     'tracking': {'carrier': 'Bluedart', 'tracking_id': 'BD12345IN'}}},
#   {'order_id': 'ORD1002',
#    'customer': {'name': 'Arjun Singh',
#     'contact': {'email': 'arjun@example.com', 'phone': '9988776655'}},
#    'items': [{'item_id': 'I103', 'name': 'Keyboard', 'price': 2500, 'qty': 1}],
#    'shipping': {'address': 'Salt Lake, Kolkata',
#     'method': 'Standard',
#     'tracking': {'carrier': 'Delhivery', 'tracking_id': 'DL99887IN'}}}]}

# %%
pd.DataFrame(data)
# Out:
#                                               orders
# 0  {'order_id': 'ORD1001', 'customer': {'name': '...
# 1  {'order_id': 'ORD1002', 'customer': {'name': '...

# %%
# From API

# %%
pd.read_json("https://dummy-json.mock.beeceptor.com/continents")
# Out:
#   code           name  areaSqKm  population  \
# 0   AF         Africa  30370000  1340598000
# 1   AN     Antarctica  14000000        1000
# 2   AS           Asia  44579000  4641055000
# 3   EU         Europe  10180000   747636000
# 4   NA  North America  24709000   579750000
# 5   OC        Oceania   8500000    43155000
# 6   SA  South America  17840000   426768000
#
#                                    lines  countries  \
# 0              [Equator, Prime Meridian]         54
# 1     [Antarctic Circle, 180th Meridian]          0
# 2            [Equator, Tropic of Cancer]         49
# 3        [Prime Meridian, Arctic Circle]         44
# 4      [Tropic of Cancer, Arctic Circle]         23
# 5  [Tropic of Capricorn, 180th Meridian]         14
# 6         [Equator, Tropic of Capricorn]         12
#
#                                           oceans  \
# 0                 [Atlantic Ocean, Indian Ocean]
# 1                               [Southern Ocean]
# ...

# %%
api_data = pd.read_json("https://dummy-json.mock.beeceptor.com/continents")

# %%
api_data
# Out:
#   code           name  areaSqKm  population  \
# 0   AF         Africa  30370000  1340598000
# 1   AN     Antarctica  14000000        1000
# 2   AS           Asia  44579000  4641055000
# 3   EU         Europe  10180000   747636000
# 4   NA  North America  24709000   579750000
# 5   OC        Oceania   8500000    43155000
# 6   SA  South America  17840000   426768000
#
#                                    lines  countries  \
# 0              [Equator, Prime Meridian]         54
# 1     [Antarctic Circle, 180th Meridian]          0
# 2            [Equator, Tropic of Cancer]         49
# 3        [Prime Meridian, Arctic Circle]         44
# 4      [Tropic of Cancer, Arctic Circle]         23
# 5  [Tropic of Capricorn, 180th Meridian]         14
# 6         [Equator, Tropic of Capricorn]         12
#
#                                           oceans  \
# 0                 [Atlantic Ocean, Indian Ocean]
# 1                               [Southern Ocean]
# ...

# %%
apidata2 = pd.read_json("https://fake-json-api.mock.beeceptor.com/companies")

# %%
apidata2
# Out:
#     id                         name                 address         zip  \
# 0    1                  Moore Group       452 Waterloo Road  59721-2470
# 1    2         D&#x27;Amore - Robel      15671 The Paddocks       55452
# 2    3  Stracke, Price and Homenick        770 Nannie Ports       61239
# 3    4  Cassin, Gusikowski and Hane  13259 Domenico Prairie       18552
# 4    4             Parisian - Morar       4259 Pinfold Lane       01690
# 5    5   Russel, Yost and Bergstrom   5929 Lessie Junctions  41347-4164
# 6    6            Padberg - Roberts      9764 W Lake Street  17081-0082
# 7    7      Yost, Crist and Schultz      88993 W Oak Street       92898
# 8    8                Berge - Weber       3208 Brakus Flats  07617-7575
# 9    9    Donnelly, Boyer and Hauck          3122 Woodlands       99047
# 10  10               Upton - Marvin     73731 Audrey Spring       27489
#
#                         country  employeeCount    industry   marketCap  \
# ...

# %%
# From html

# %%
dflist = pd.read_html("FIFA World Cup - Wikipedia.html")

# %%
dflist
# Out:
# [                                   0                                  1
#  0                                NaN                                NaN
#  1                       Organiser(s)                               FIFA
#  2                            Founded                 1930; 95 years ago
#  3                             Region                      International
#  4                              Teams          32 (48 from 2026 onwards)
#  5               Related competitions             FIFA Women's World Cup
#  6                  Current champions              Argentina (3rd title)
#  7                 Most championships                  Brazil (5 titles)
#  8                            Website                  fifa.com/worldcup
#  9  2026 FIFA World Cup qualification  2026 FIFA World Cup qualification,
#                                                     0
#  0                   Argentina, the current champions
#  1                                        Tournaments
# ...

# %%
dflist[4]
# Out:
#      0     1                              2   3   \
# 0   Ed.  Year                          Hosts NaN
# 1   Ed.  Year                          Hosts NaN
# 2     1  1930                        Uruguay NaN
# 3     2  1934                          Italy NaN
# 4     3  1938                         France NaN
# 5     –  1942                            NaN NaN
# 6     –  1946                            NaN NaN
# 7     4  1950                         Brazil NaN
# 8     5  1954                    Switzerland NaN
# 9     6  1958                         Sweden NaN
# 10    7  1962                          Chile NaN
# 11    8  1966                        England NaN
# 12    9  1970                         Mexico NaN
# 13   10  1974                   West Germany NaN
# 14   11  1978                      Argentina NaN
# 15   12  1982                          Spain NaN
# 16   13  1986                         Mexico NaN
# 17   14  1990                          Italy NaN
# ...

# %%
# From Excel

# %%
df = pd.read_excel("empdata.xlsx",sheet_name='Pune','HYD','Chennai')
# Out:
#   Cell In[46], line 1
#     df = pd.read_excel("empdata.xlsx",sheet_name='Pune','HYD','Chennai')
#                                                                        ^
# SyntaxError: positional argument follows keyword argument

# %%
df
# Out:
#       id    name   dept Region
# 0    434  keshav     IT   Pune
# 1  43423  Pratik     HR   Pune
# 2  43434  Sonali  Admin   Pune
# 3  32342    Amit     HR   Pune
