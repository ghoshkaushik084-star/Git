# %%
print("Hello World")
# Out:
# Hello World

# %%
help("keywords")
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %%
name = input()
# Out:
#  Rahul

# %%
print (name)
# Out:
# Rahul

# %%
print (type(name))
# Out:
# <class 'str'>

# %%
----- # Separator

# %%
print ("Kaushik", "Sonali", "Sneha", 42, 45, 32)
# Out:
# Kaushik Sonali Sneha 42 45 32

# %%
print ("Kaushik","Sonali","Sneha",42,45,32)
# Out:
# Kaushik Sonali Sneha 42 45 32

# %%
print ("Kaushik", "Sonali", "Sneha", 42.30, 45.21, 32.32)
# Out:
# Kaushik Sonali Sneha 42.3 45.21 32.32

# %%
----- # Separator and changing by default separator - changing from by default to user value separator

# %%
print ("Kaushik", "Sonali", "Sneha", 42.30, 45.21, 32.32, sep=',')
# Out:
# Kaushik,Sonali,Sneha,42.3,45.21,32.32

# %%
print ("Kaushik", "Sonali", "Sneha", 42.30, 45.21, 32.32, sep='$')
# Out:
# Kaushik$Sonali$Sneha$42.3$45.21$32.32

# %%
print ("Kaushik", "Sonali", "Sneha", 42.30, 45.21, 32.32, sep='\n')
# Out:
# Kaushik
# Sonali
# Sneha
# 42.3
# 45.21
# 32.32

# %%
--- '\n' is separator for next line

# %%
--- Remove

# %%
p=['abc',80,52,35]

# %%
p
# Out:
# ['abc', 80, 52, 35]

# %%
p.remove(80)

# %%
p
# Out:
# ['abc', 52, 35]

# %%
['abc', 52, 35].remove(52)

# %%
p.pop()
# Out:
# 35

# %%
p
# Out:
# ['abc', 52]

# %%
p.clear()

# %%
p
# Out:
# []

# %%
p = (75434, 4396, 10004, 80000, 75000, 50000, 40000, 20000)

# %%
p
# Out:
# (75434, 4396, 10004, 80000, 75000, 50000, 40000, 20000)

# %%
p.sort
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 p.sort
#
# AttributeError: 'tuple' object has no attribute 'sort'

# %%
print (type(p))
# Out:
# <class 'tuple'>

# %%
p = [75434, 4396, 10004, 80000, 75000, 50000, 40000, 20000]

# %%
p
# Out:
# [75434, 4396, 10004, 80000, 75000, 50000, 40000, 20000]

# %%
print (type(p))
# Out:
# <class 'list'>

# %%
p.sort()

# %%
p
# Out:
# [4396, 10004, 20000, 40000, 50000, 75000, 75434, 80000]

# %%
sal = [4396, 10004, 20000, 40000, 50000, 75000, 75434, 80000, 35000, 15000]

# %%
sal.count(80000)
# Out:
# 1

# %%
sal
# Out:
# [4396, 10004, 20000, 40000, 50000, 75000, 75434, 80000, 35000, 15000]

# %%
sal.sort()

# %%
sal
# Out:
# [4396, 10004, 15000, 20000, 35000, 40000, 50000, 75000, 75434, 80000]

# %%
sal.sort(reverse=True)

# %%
sal
# Out:
# [80000, 75434, 75000, 50000, 40000, 35000, 20000, 15000, 10004, 4396]

# %%
p
# Out:
# [4396, 10004, 20000, 40000, 50000, 75000, 75434, 80000]

# %%
sal.count(80000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 sal.count(80000)
#
# NameError: name 'sal' is not defined

# %%
kau = ['abc', 80, 52, 35]

# %%
kau
# Out:
# ['abc', 80, 52, 35]

# %%
kau.reverse()

# %%
kau.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 kau.sort()
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
ap = [3,8,7,6,]

# %%
ap
# Out:
# [3, 8, 7, 6]

# %%
ap.sort()

# %%
ap
# Out:
# [3, 6, 7, 8]

# %%
ap
# Out:
# [3, 8, 7, 6]

# %%
ap.reverse()

# %%
ap
# Out:
# [3, 8, 7, 6]

# %%
ap.sort()

# %%
ap
# Out:
# [3, 6, 7, 8]

# %%
ap.sort(reverse=True)

# %%
ap
# Out:
# [8, 7, 6, 3]

# %%
ap
# Out:
# [3, 8, 7, 6]

# %%
ap.sort(reverse=False)

# %%
ap
# Out:
# [3, 6, 7, 8]

# %%
email = input ('enter email')
# Out:
# enter email kaushikghosh@gmail.com

# %%
password = input ('enter password')
# Out:
# enter password 12345

# %%
if email == 'kaushikghosh@gmail.com' and password == '12345':
    print ('Welcome')
elif email == 'kaushikghosh@gmail.com' and password != '12345':
    # tell the user
    print ('Incorrect password')
    password = input ('Enter password again')
    if password == '12345':
        print ('Welcome finally')
    else:
        print ('beta tum se na ho payega')
else:
    print ('Invalid')
# Out:
# Welcome

# %%
p = {100,300,500,600,800}

# %%
p
# Out:
# {100, 300, 500, 600, 800}

# %%
p = [100,300,500,600,800]

# %%
p
# Out:
# [100, 300, 500, 600, 800]

# %%
p.index (300)
# Out:
# 1

# %%
"2,3,4" * 5
# Out:
# '2,3,42,3,42,3,42,3,42,3,4'

# %%
[2,5,8] * 4
# Out:
# [2, 5, 8, 2, 5, 8, 2, 5, 8, 2, 5, 8]

# %%
50/6
# Out:
# 8.333333333333334

# %%
50//6
# Out:
# 8

# %%
import math

# %%
math.ceil(50/6)
# Out:
# 9

# %%
12**12
# Out:
# 8916100448256

# %%
2**2
# Out:
# 4

# %%
5**2
# Out:
# 25

# %%
9**2
# Out:
# 81

# %%
3**2
# Out:
# 9

# %%
3**3
# Out:
# 27

# %%
# Tuple packing unpacking

# %%
a = 2
b = 3
c = 4

# %%
t = a, b, c

# %%
t
# Out:
# (2, 3, 4)

# %%
print (type(t))
# Out:
# <class 'tuple'>

# %%
e,f,g = t

# %%
t
# Out:
# (2, 3, 4)

# %%
e,f,g
# Out:
# (2, 3, 4)

# %%
print (e,f,g)
# Out:
# 2 3 4

# %%
p = [2, 35, 85, 'abc', 633, 966]

# %%
p
# Out:
# [2, 35, 85, 'abc', 633, 966]

# %%
print(type(p))
# Out:
# <class 'list'>

# %%
p = {2, 35, 85, 'abc', 633, 966}

# %%
p
# Out:
# {2, 35, 633, 85, 966, 'abc'}

# %%
 null_set = set()

# %%
null_set
# Out:
# set()

# %%
p = {45, 16, 75, 56}

# %%
p
# Out:
# {16, 45, 56, 75}

# %%
p.add (82)

# %%
p
# Out:
# {16, 45, 56, 75, 82}

# %%
p.add (99)

# %%
p
# Out:
# {16, 45, 56, 75, 82, 99}

# %%
p.add (29)

# %%
p
# Out:
# {16, 29, 45, 56, 75, 82, 99}

# %%
p
# Out:
# {16, 29, 45, 56, 75, 82, 99}

# %%
type(p)
# Out:
# set

# %%
p.type(-1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 p.type(-1)
#
# AttributeError: 'set' object has no attribute 'type'

# %%
p
# Out:
# {16, 29, 45, 56, 75, 82, 99}

# %%
p.discard(29)

# %%
p
# Out:
# {16, 45, 56, 75, 82, 99}

# %%
p.discard(100)

# %%
p
# Out:
# {16, 45, 56, 75, 82, 99}

# %%
p.pop()
# Out:
# 99

# %%
p
# Out:
# {16, 45, 56, 75, 82}

# %%
p.clear()

# %%
p
# Out:
# set()

# %%
loan = {'keshav', 'amit', 'pravin', 'sonali', 'rahul'}

# %%
loan
# Out:
# {'amit', 'keshav', 'pravin', 'rahul', 'sonali'}

# %%
credit = {'sonali', 'rahul', 'john', 'justin'}

# %%
credit
# Out:
# {'john', 'justin', 'rahul', 'sonali'}

# %%
loan.union(credit)
# Out:
# {'amit', 'john', 'justin', 'keshav', 'pravin', 'rahul', 'sonali'}

# %%
loan.intersection(credit)
# Out:
# {'amit', 'rahul', 'sonali'}

# %%
loan.difference(credit)
# Out:
# {'keshav', 'pravin'}

# %%
loan.symmetric_difference(credit)
# Out:
# {'john', 'justin', 'keshav', 'pravin'}

# %%
p = {1,2,3,4,5,7,8,9}

# %%
p
# Out:
# {1, 2, 3, 4, 5, 7, 8, 9}

# %%
p1 = {3,4,5}

# %%
p1
# Out:
# {3, 4, 5}

# %%
p.issuperset(p1)
# Out:
# True

# %%
p1.issubset(p)
# Out:
# True

# %%
loan.symmetric_difference_update(credit)

# %%
loan
# Out:
# {'amit', 'john', 'justin', 'keshav', 'pravin'}
